# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json 
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# List for holding lat_lngs & cities
lat_lngs = []
cities = []
countries = []
# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=25)
lngs = np.random.uniform(low=-180.000, high=180.000, size=25)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country)


# Print the city count to confirm sufficient count
print(len(cities))
print(type(cities))
print(countries)
# Out:
# 23
# <class 'list'>
# ['pg', 'au', 'kz', 'ar', 'ck', 'jp', 'br', 'ca', 'to', 'za', 'ar', 'bm', 'ru', 'no', 'er', 'au', 'pf', 'ml', 'au', 'cl', 'pf', 'mu', 'fi']

# %%
city_data = list(zip(cities, countries))
city_data_df = pd.DataFrame(city_data, columns = ['City', 'Country'])
city_data_df
# Out:
#              City Country
# 0        lorengau      pg
# 1          hobart      au
# 2           atasu      kz
# 3         ushuaia      ar
# 4          avarua      ck
# 5          hasaki      jp
# 6       caravelas      br
# 7           lumby      ca
# 8           vaini      to
# 9       cape town      za
# 10  mar del plata      ar
# 11       hamilton      bm
# 12    skovorodino      ru
# 13          floro      no
# 14          ginda      er
# 15  alice springs      au
# 16        rikitea      pf
# 17      taoudenni      ml
# 18         albany      au
# 19           lebu      cl
# 20         atuona      pf
# 21      mahebourg      mu
# 22        kokkola      fi

# %%
# get actual lat and lng for each city found
city_data_df['Latitude'] = ""
city_data_df['Longitude'] = ""
base_url = 'http://api.openweathermap.org/data/2.5/weather?q'
units = 'imperial'
city_data_df
# Out:
#              City Country Latitude Longitude
# 0        lorengau      pg
# 1          hobart      au
# 2           atasu      kz
# 3         ushuaia      ar
# 4          avarua      ck
# 5          hasaki      jp
# 6       caravelas      br
# 7           lumby      ca
# 8           vaini      to
# 9       cape town      za
# 10  mar del plata      ar
# 11       hamilton      bm
# 12    skovorodino      ru
# 13          floro      no
# 14          ginda      er
# 15  alice springs      au
# 16        rikitea      pf
# 17      taoudenni      ml
# 18         albany      au
# 19           lebu      cl
# 20         atuona      pf
# 21      mahebourg      mu
# 22        kokkola      fi

# %%
for index1, rows in city_data_df.iterrows():
    lat_lng_url = f'{base_url}={rows[0]}&appid={weather_api_key}&units={units}'
    #print(f"Retrieving Results for Index {index}: {row[0]}.")
    response1 = requests.get(lat_lng_url).json()

    try:
        #print("All data found.")
        
        city_data_df.loc[index1, 'Latitude'] = response1['coord']['lat']
        city_data_df.loc[index1, 'Longitude'] = response1['coord']['lon']
        print("Data found.")
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
    time.sleep(1)
    print("------------")
# Out:
# Data found.
# ------------
# Data found.
# ------------
# Data found.
# ------------
# Data found.
# ------------
# Data found.
# ------------
# Data found.
# ------------
# Data found.
# ------------
# Data found.
# ------------
# Data found.
# ------------
# Data found.
# ------------
# Data found.
# ------------
# Data found.
# ------------
# Data found.
# ------------
# Data found.
# ------------
# Data found.
# ------------
# Data found.
# ------------
# Data found.
# ------------
# Data found.
# ------------
# Data found.
# ------------
# Data found.
# ------------
# Data found.
# ------------
# Data found.
# ------------
# Data found.
# ------------

# %%
city_data_df
# Out:
#              City Country Latitude Longitude
# 0        lorengau      pg    -2.02    147.27
# 1          hobart      au   -42.88    147.33
# 2           atasu      kz    48.68     71.64
# 3         ushuaia      ar    -54.8     -68.3
# 4          avarua      ck   -21.21   -159.78
# 5          hasaki      jp    35.73    140.83
# 6       caravelas      br   -17.71    -39.25
# 7           lumby      ca    50.25   -118.97
# 8           vaini      to    -21.2    -175.2
# 9       cape town      za   -33.93     18.42
# 10  mar del plata      ar      -38    -57.56
# 11       hamilton      bm    39.18    -84.53
# 12    skovorodino      ru    53.98    123.92
# 13          floro      no     61.6      5.03
# 14          ginda      er    30.69     78.49
# 15  alice springs      au    -23.7    133.88
# 16        rikitea      pf   -23.12   -134.97
# 17      taoudenni      ml    22.68     -3.98
# 18         albany      au     42.6    -73.97
# 19           lebu      cl   -37.62    -73.65
# 20         atuona      pf     -9.8   -139.03
# 21      mahebourg      mu   -20.41      57.7
# 22        kokkola      fi    63.84     23.13

# %%
# Remove rows with no values
# Set empty strings to 'NaN'
nan_value = float("NaN")
city_data_df.replace("", nan_value, inplace = True)
# Drop rows with any NaN
city_data_df.dropna(how = 'any', inplace = True)
city_data_df
# Out:
#              City Country Latitude Longitude
# 0        lorengau      pg    -2.02    147.27
# 1          hobart      au   -42.88    147.33
# 2           atasu      kz    48.68     71.64
# 3         ushuaia      ar    -54.8     -68.3
# 4          avarua      ck   -21.21   -159.78
# 5          hasaki      jp    35.73    140.83
# 6       caravelas      br   -17.71    -39.25
# 7           lumby      ca    50.25   -118.97
# 8           vaini      to    -21.2    -175.2
# 9       cape town      za   -33.93     18.42
# 10  mar del plata      ar      -38    -57.56
# 11       hamilton      bm    39.18    -84.53
# 12    skovorodino      ru    53.98    123.92
# 13          floro      no     61.6      5.03
# 14          ginda      er    30.69     78.49
# 15  alice springs      au    -23.7    133.88
# 16        rikitea      pf   -23.12   -134.97
# 17      taoudenni      ml    22.68     -3.98
# 18         albany      au     42.6    -73.97
# 19           lebu      cl   -37.62    -73.65
# 20         atuona      pf     -9.8   -139.03
# 21      mahebourg      mu   -20.41      57.7
# 22        kokkola      fi    63.84     23.13

# %%
url = 'http://api.openweathermap.org/data/2.5/onecall?'
units = 'imperial'
city_data_df['Date'] = ""
city_data_df['Temp (Day)'] = ""
city_data_df['Humidity'] = ""
city_data_df['Cloudiness'] = ""
city_data_df['Wind Speed'] = ""
city_data_df.head()
# Out:
#        City Country Latitude Longitude Date Temp Humidity Cloudiness  \
# 0  lorengau      pg    -2.02    147.27
# 1    hobart      au   -42.88    147.33
# 2     atasu      kz    48.68     71.64
# 3   ushuaia      ar    -54.8     -68.3
# 4    avarua      ck   -21.21   -159.78
#
#   Wind Speed
# 0
# 1
# 2
# 3
# 4

# %%
for index, row in city_data_df.iterrows():
    query_url = f'{url}appid={weather_api_key}&lat={row[2]}&lon={row[3]}&units={units}'
    print(f"Retrieving Results for Index {index}: {row[0]}.")
    response = requests.get(query_url).json()
    

    try:
        print("All data found.")
        
        city_data_df.loc[index, 'Date'] = response['daily'][0]['dt']
        city_data_df.loc[index, 'Temp (Day)'] = response['daily'][0]['temp']['day']
        city_data_df.loc[index, 'Humidity'] = response['daily'][0]['humidity']
        city_data_df.loc[index, 'Cloudiness'] = response['daily'][0]['clouds']
        city_data_df.loc[index, 'Wind Speed'] = response['daily'][0]['wind_speed']
        
    except (KeyError, IndexError):
        print("City not found... skipping.")
    
    time.sleep(1)    
    print("------------")
# Out:
# Retrieving Results for Index 0: lorengau.
# All data found.
# ------------
# Retrieving Results for Index 1: hobart.
# All data found.
# ------------
# Retrieving Results for Index 2: atasu.
# All data found.
# ------------
# Retrieving Results for Index 3: ushuaia.
# All data found.
# ------------
# Retrieving Results for Index 4: avarua.
# All data found.
# ------------
# Retrieving Results for Index 5: hasaki.
# All data found.
# ------------
# Retrieving Results for Index 6: caravelas.
# All data found.
# ------------
# Retrieving Results for Index 7: lumby.
# All data found.
# ------------
# Retrieving Results for Index 8: vaini.
# All data found.
# ------------
# Retrieving Results for Index 9: cape town.
# All data found.
# ------------
# Retrieving Results for Index 10: mar del plata.
# All data found.
# ------------
# Retrieving Results for Index 11: hamilton.
# All data found.
# ------------
# Retrieving Results for Index 12: skovorodino.
# All data found.
# ------------
# Retrieving Results for Index 13: floro.
# All data found.
# ------------
# Retrieving Results for Index 14: ginda.
# All data found.
# ------------
# Retrieving Results for Index 15: alice springs.
# All data found.
# ------------
# Retrieving Results for Index 16: rikitea.
# All data found.
# ------------
# Retrieving Results for Index 17: taoudenni.
# All data found.
# ------------
# Retrieving Results for Index 18: albany.
# All data found.
# ------------
# Retrieving Results for Index 19: lebu.
# All data found.
# ------------
# Retrieving Results for Index 20: atuona.
# All data found.
# ------------
# Retrieving Results for Index 21: mahebourg.
# All data found.
# ------------
# Retrieving Results for Index 22: kokkola.
# All data found.
# ------------

# %%
city_data_df.head()
city_data_df.to_csv('city_test4.csv')

# %%
temp = response['daily'][0]['temp']['day']
print(temp)
humidity = response['daily'][0]['humidity']
print(humidity)
cloudiness = response['daily'][0]['clouds']
print(cloudiness)
wind_speed = response['daily'][0]['wind_speed']
print(wind_speed)


#for city in cities:
# Out:
# 69.55
# 83
# 90
# 15.14

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-bb29283669b9> in <module>
# ----> 1 citipy.city_coordinate_key('atlanta')
#
# TypeError: 'tuple' object is not callable

# %%
city = citipy.nearest_city(56.5,-112)
city

# %%
world_cities = citipy.WORLD_CITIES_DICT

# %%
city_3 = citipy.nearest_city(33.7123,-84.1052)
city_3.country_code
# Out:
# 'us'

# %%
city2 = citipy.nearest_city([world_cities[7]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-ddbb3309d580> in <module>
# ----> 1 city2 = citipy.nearest_city([world_cities[7]])
#
# KeyError: 7

# %%
url = 'https://api.openweathermap.org/data/2.5/onecall?lat=33.7123&lon=-84.1052&appid=9ef57f54a2dbe47f5ec209e2b0ed3107'
response = requests.get(url)
response_json = response.json()
print(json.dumps(response_json, indent = 4))
# Out:
# {
#     "lat": 33.71,
#     "lon": -84.11,
#     "timezone": "America/New_York",
#     "current": {
#         "dt": 1586919441,
#         "sunrise": 1586862371,
#         "sunset": 1586909190,
#         "temp": 285.24,
#         "feels_like": 278.87,
#         "pressure": 1016,
#         "humidity": 50,
#         "dew_point": 275.14,
#         "uvi": 9.81,
#         "clouds": 20,
#         "visibility": 16093,
#         "wind_speed": 6.7,
#         "wind_deg": 330,
#         "weather": [
#             {
#                 "id": 801,
#                 "main": "Clouds",
#                 "description": "few clouds",
#                 "icon": "02n"
#             }
#         ]
#     },
#     "hourly": [
#         {
#             "dt": 1586916000,
#             "temp": 285.24,
#             "feels_like": 280.91,
#             "pressure": 1016,
#             "humidity": 50,
#             "dew_point": 275.14,
#             "clouds": 20,
#             "wind_speed": 3.79,
#             "wind_deg": 323,
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ]
#         },
#         {
#             "dt": 1586919600,
#             "temp": 285.45,
#             "feels_like": 281.12,
#             "pressure": 1016,
#             "humidity": 50,
#             "dew_point": 275.34,
#             "clouds": 10,
#             "wind_speed": 3.84,
#             "wind_deg": 326,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "dt": 1586923200,
#             "temp": 285.31,
#             "feels_like": 281,
#             "pressure": 1016,
#             "humidity": 50,
#             "dew_point": 275.21,
#             "clouds": 4,
#             "wind_speed": 3.78,
#             "wind_deg": 326,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "dt": 1586926800,
#             "temp": 284.98,
#             "feels_like": 280.53,
#             "pressure": 1016,
#             "humidity": 50,
#             "dew_point": 274.9,
#             "clouds": 1,
#             "wind_speed": 3.91,
#             "wind_deg": 320,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "dt": 1586930400,
#             "temp": 284.35,
#             "feels_like": 279.67,
#             "pressure": 1016,
#             "humidity": 51,
#             "dew_point": 274.6,
#             "clouds": 0,
#             "wind_speed": 4.16,
#             "wind_deg": 316,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "dt": 1586934000,
#             "temp": 283.29,
#             "feels_like": 278.37,
#             "pressure": 1016,
#             "humidity": 52,
#             "dew_point": 275.27,
#             "clouds": 0,
#             "wind_speed": 4.35,
#             "wind_deg": 315,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "dt": 1586937600,
#             "temp": 282.35,
#             "feels_like": 277.45,
#             "pressure": 1016,
#             "humidity": 54,
#             "dew_point": 274.76,
#             "clouds": 0,
#             "wind_speed": 4.24,
#             "wind_deg": 314,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "dt": 1586941200,
#             "temp": 281.72,
#             "feels_like": 276.73,
#             "pressure": 1016,
#             "humidity": 55,
#             "dew_point": 274.45,
#             "clouds": 2,
#             "wind_speed": 4.3,
#             "wind_deg": 314,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "dt": 1586944800,
#             "temp": 281.29,
#             "feels_like": 276.26,
#             "pressure": 1017,
#             "humidity": 54,
#             "dew_point": 273.99,
#             "clouds": 11,
#             "wind_speed": 4.22,
#             "wind_deg": 319,
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ]
#         },
#         {
#             "dt": 1586948400,
#             "temp": 280.73,
#             "feels_like": 275.71,
#             "pressure": 1017,
#             "humidity": 54,
#             "dew_point": 273.23,
#             "clouds": 14,
#             "wind_speed": 4.11,
#             "wind_deg": 323,
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ]
#         },
#         {
#             "dt": 1586952000,
#             "temp": 280.79,
#             "feels_like": 275.9,
#             "pressure": 1017,
#             "humidity": 53,
#             "dew_point": 273.08,
#             "clouds": 12,
#             "wind_speed": 3.88,
#             "wind_deg": 326,
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02d"
#                 }
#             ]
#         },
#         {
#             "dt": 1586955600,
#             "temp": 282.02,
#             "feels_like": 277.35,
#             "pressure": 1017,
#             "humidity": 48,
#             "dew_point": 272.9,
#             "clouds": 25,
#             "wind_speed": 3.53,
#             "wind_deg": 330,
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ]
#         },
#         {
#             "dt": 1586959200,
#             "temp": 283.82,
#             "feels_like": 279.17,
#             "pressure": 1017,
#             "humidity": 42,
#             "dew_point": 272.77,
#             "clouds": 39,
#             "wind_speed": 3.47,
#             "wind_deg": 332,
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ]
#         },
#         {
#             "dt": 1586962800,
#             "temp": 285.96,
#             "feels_like": 281.51,
#             "pressure": 1017,
#             "humidity": 37,
#             "dew_point": 272.79,
#             "clouds": 43,
#             "wind_speed": 3.22,
#             "wind_deg": 337,
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ]
#         },
#         {
#             "dt": 1586966400,
#             "temp": 288.15,
#             "feels_like": 283.82,
#             "pressure": 1017,
#             "humidity": 31,
#             "dew_point": 272.35,
#             "clouds": 55,
#             "wind_speed": 2.96,
#             "wind_deg": 339,
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ]
#         },
#         {
#             "dt": 1586970000,
#             "temp": 290.09,
#             "feels_like": 285.66,
#             "pressure": 1016,
#             "humidity": 27,
#             "dew_point": 271.15,
#             "clouds": 44,
#             "wind_speed": 3.06,
#             "wind_deg": 331,
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ]
#         },
#         {
#             "dt": 1586973600,
#             "temp": 291.17,
#             "feels_like": 286.43,
#             "pressure": 1016,
#             "humidity": 25,
#             "dew_point": 269.79,
#             "clouds": 37,
#             "wind_speed": 3.48,
#             "wind_deg": 322,
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ]
#         },
#         {
#             "dt": 1586977200,
#             "temp": 291.7,
#             "feels_like": 286.38,
#             "pressure": 1016,
#             "humidity": 23,
#             "dew_point": 268.57,
#             "clouds": 0,
#             "wind_speed": 4.19,
#             "wind_deg": 313,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
#         },
#         {
#             "dt": 1586980800,
#             "temp": 291.82,
#             "feels_like": 286.24,
#             "pressure": 1015,
#             "humidity": 23,
#             "dew_point": 267.48,
#             "clouds": 0,
#             "wind_speed": 4.58,
#             "wind_deg": 311,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
#         },
#         {
#             "dt": 1586984400,
#             "temp": 291.4,
#             "feels_like": 285.68,
#             "pressure": 1015,
#             "humidity": 23,
#             "dew_point": 266.93,
#             "clouds": 0,
#             "wind_speed": 4.72,
#             "wind_deg": 312,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
#         },
#         {
#             "dt": 1586988000,
#             "temp": 290.44,
#             "feels_like": 284.73,
#             "pressure": 1016,
#             "humidity": 25,
#             "dew_point": 268.39,
#             "clouds": 0,
#             "wind_speed": 4.77,
#             "wind_deg": 316,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
#         },
#         {
#             "dt": 1586991600,
#             "temp": 288.77,
#             "feels_like": 283.26,
#             "pressure": 1016,
#             "humidity": 29,
#             "dew_point": 270.4,
#             "clouds": 0,
#             "wind_speed": 4.58,
#             "wind_deg": 320,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
#         },
#         {
#             "dt": 1586995200,
#             "temp": 286.38,
#             "feels_like": 280.82,
#             "pressure": 1017,
#             "humidity": 33,
#             "dew_point": 269.62,
#             "clouds": 2,
#             "wind_speed": 4.59,
#             "wind_deg": 332,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
#         },
#         {
#             "dt": 1586998800,
#             "temp": 285.35,
#             "feels_like": 279.67,
#             "pressure": 1019,
#             "humidity": 35,
#             "dew_point": 268.35,
#             "clouds": 3,
#             "wind_speed": 4.74,
#             "wind_deg": 335,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "dt": 1587002400,
#             "temp": 284.6,
#             "feels_like": 278.97,
#             "pressure": 1020,
#             "humidity": 36,
#             "dew_point": 267.18,
#             "clouds": 16,
#             "wind_speed": 4.62,
#             "wind_deg": 341,
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ]
#         },
#         {
#             "dt": 1587006000,
#             "temp": 284.18,
#             "feels_like": 278.39,
#             "pressure": 1021,
#             "humidity": 36,
#             "dew_point": 266.25,
#             "clouds": 11,
#             "wind_speed": 4.79,
#             "wind_deg": 343,
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ]
#         },
#         {
#             "dt": 1587009600,
#             "temp": 283.66,
#             "feels_like": 278.08,
#             "pressure": 1021,
#             "humidity": 37,
#             "dew_point": 265.89,
#             "clouds": 9,
#             "wind_speed": 4.47,
#             "wind_deg": 343,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "dt": 1587013200,
#             "temp": 283.24,
#             "feels_like": 277.7,
#             "pressure": 1022,
#             "humidity": 38,
#             "dew_point": 265.63,
#             "clouds": 7,
#             "wind_speed": 4.41,
#             "wind_deg": 347,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "dt": 1587016800,
#             "temp": 282.81,
#             "feels_like": 277.46,
#             "pressure": 1022,
#             "humidity": 39,
#             "dew_point": 265.54,
#             "clouds": 6,
#             "wind_speed": 4.13,
#             "wind_deg": 357,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "dt": 1587020400,
#             "temp": 282.22,
#             "feels_like": 277.26,
#             "pressure": 1022,
#             "humidity": 41,
#             "dew_point": 265.87,
#             "clouds": 0,
#             "wind_speed": 3.6,
#             "wind_deg": 357,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "dt": 1587024000,
#             "temp": 281.9,
#             "feels_like": 277.03,
#             "pressure": 1023,
#             "humidity": 43,
#             "dew_point": 267.48,
#             "clouds": 0,
#             "wind_speed": 3.53,
#             "wind_deg": 355,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "dt": 1587027600,
#             "temp": 281.45,
#             "feels_like": 276.72,
#             "pressure": 1023,
#             "humidity": 44,
#             "dew_point": 266.72,
#             "clouds": 0,
#             "wind_speed": 3.31,
#             "wind_deg": 356,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "dt": 1587031200,
#             "temp": 281.11,
#             "feels_like": 276.38,
#             "pressure": 1023,
#             "humidity": 45,
#             "dew_point": 267.35,
#             "clouds": 0,
#             "wind_speed": 3.31,
#             "wind_deg": 1,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "dt": 1587034800,
#             "temp": 280.73,
#             "feels_like": 276.25,
#             "pressure": 1024,
#             "humidity": 47,
#             "dew_point": 267.9,
#             "clouds": 0,
#             "wind_speed": 2.99,
#             "wind_deg": 7,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         },
#         {
#             "dt": 1587038400,
#             "temp": 281.43,
#             "feels_like": 277.26,
#             "pressure": 1025,
#             "humidity": 46,
#             "dew_point": 269.6,
#             "clouds": 0,
#             "wind_speed": 2.61,
#             "wind_deg": 17,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
#         },
#         {
#             "dt": 1587042000,
#             "temp": 283.94,
#             "feels_like": 279.73,
#             "pressure": 1025,
#             "humidity": 40,
#             "dew_point": 270.61,
#             "clouds": 0,
#             "wind_speed": 2.74,
#             "wind_deg": 25,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
#         },
#         {
#             "dt": 1587045600,
#             "temp": 286.48,
#             "feels_like": 282.56,
#             "pressure": 1025,
#             "humidity": 34,
#             "dew_point": 271.56,
#             "clouds": 0,
#             "wind_speed": 2.33,
#             "wind_deg": 48,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
#         },
#         {
#             "dt": 1587049200,
#             "temp": 288.65,
#             "feels_like": 284.8,
#             "pressure": 1025,
#             "humidity": 30,
#             "dew_point": 271.51,
#             "clouds": 0,
#             "wind_speed": 2.27,
#             "wind_deg": 43,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
#         },
#         {
#             "dt": 1587052800,
#             "temp": 290.44,
#             "feels_like": 286.69,
#             "pressure": 1024,
#             "humidity": 27,
#             "dew_point": 271.65,
#             "clouds": 0,
#             "wind_speed": 2.15,
#             "wind_deg": 42,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
#         },
#         {
#             "dt": 1587056400,
#             "temp": 291.94,
#             "feels_like": 288.3,
#             "pressure": 1024,
#             "humidity": 24,
#             "dew_point": 271.82,
#             "clouds": 0,
#             "wind_speed": 1.94,
#             "wind_deg": 38,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
#         },
#         {
#             "dt": 1587060000,
#             "temp": 293.13,
#             "feels_like": 289.7,
#             "pressure": 1024,
#             "humidity": 23,
#             "dew_point": 272.61,
#             "clouds": 0,
#             "wind_speed": 1.71,
#             "wind_deg": 52,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
#         },
#         {
#             "dt": 1587063600,
#             "temp": 294.16,
#             "feels_like": 290.85,
#             "pressure": 1023,
#             "humidity": 21,
#             "dew_point": 272.42,
#             "clouds": 0,
#             "wind_speed": 1.47,
#             "wind_deg": 23,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
#         },
#         {
#             "dt": 1587067200,
#             "temp": 294.64,
#             "feels_like": 291.63,
#             "pressure": 1022,
#             "humidity": 21,
#             "dew_point": 272.65,
#             "clouds": 0,
#             "wind_speed": 1.12,
#             "wind_deg": 35,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
#         },
#         {
#             "dt": 1587070800,
#             "temp": 294.21,
#             "feels_like": 291.13,
#             "pressure": 1022,
#             "humidity": 21,
#             "dew_point": 272.49,
#             "clouds": 0,
#             "wind_speed": 1.15,
#             "wind_deg": 83,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
#         },
#         {
#             "dt": 1587074400,
#             "temp": 293.19,
#             "feels_like": 289.8,
#             "pressure": 1022,
#             "humidity": 23,
#             "dew_point": 272.66,
#             "clouds": 0,
#             "wind_speed": 1.66,
#             "wind_deg": 123,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
#         },
#         {
#             "dt": 1587078000,
#             "temp": 291.44,
#             "feels_like": 287.69,
#             "pressure": 1022,
#             "humidity": 34,
#             "dew_point": 276.61,
#             "clouds": 0,
#             "wind_speed": 3.01,
#             "wind_deg": 136,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
#         },
#         {
#             "dt": 1587081600,
#             "temp": 288.77,
#             "feels_like": 285.06,
#             "pressure": 1022,
#             "humidity": 40,
#             "dew_point": 276.37,
#             "clouds": 0,
#             "wind_speed": 2.93,
#             "wind_deg": 139,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ]
#         },
#         {
#             "dt": 1587085200,
#             "temp": 287.49,
#             "feels_like": 283.96,
#             "pressure": 1023,
#             "humidity": 39,
#             "dew_point": 275.17,
#             "clouds": 0,
#             "wind_speed": 2.33,
#             "wind_deg": 136,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ]
#         }
#     ],
#     "daily": [
#         {
#             "dt": 1586883600,
#             "sunrise": 1586862371,
#             "sunset": 1586909190,
#             "temp": {
#                 "day": 285.24,
#                 "min": 283.53,
#                 "max": 285.24,
#                 "night": 283.53,
#                 "eve": 285.24,
#                 "morn": 285.24
#             },
#             "feels_like": {
#                 "day": 280.71,
#                 "night": 278.78,
#                 "eve": 280.71,
#                 "morn": 280.71
#             },
#             "pressure": 1016,
#             "humidity": 50,
#             "dew_point": 275.14,
#             "wind_speed": 4.07,
#             "wind_deg": 318,
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02d"
#                 }
#             ],
#             "clouds": 20,
#             "uvi": 9.81
#         },
#         {
#             "dt": 1586970000,
#             "sunrise": 1586948697,
#             "sunset": 1586995636,
#             "temp": {
#                 "day": 291.17,
#                 "min": 280.76,
#                 "max": 291.4,
#                 "night": 282.81,
#                 "eve": 286.38,
#                 "morn": 280.76
#             },
#             "feels_like": {
#                 "day": 286.43,
#                 "night": 277.46,
#                 "eve": 280.82,
#                 "morn": 275.87
#             },
#             "pressure": 1016,
#             "humidity": 25,
#             "dew_point": 269.79,
#             "wind_speed": 3.48,
#             "wind_deg": 322,
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ],
#             "clouds": 37,
#             "uvi": 8.93
#         },
#         {
#             "dt": 1587056400,
#             "sunrise": 1587035024,
#             "sunset": 1587082081,
#             "temp": {
#                 "day": 293.13,
#                 "min": 281.43,
#                 "max": 294.21,
#                 "night": 284.27,
#                 "eve": 288.77,
#                 "morn": 281.43
#             },
#             "feels_like": {
#                 "day": 289.7,
#                 "night": 280.76,
#                 "eve": 285.06,
#                 "morn": 277.26
#             },
#             "pressure": 1024,
#             "humidity": 23,
#             "dew_point": 272.61,
#             "wind_speed": 1.71,
#             "wind_deg": 52,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": 0,
#             "uvi": 8.92
#         },
#         {
#             "dt": 1587142800,
#             "sunrise": 1587121352,
#             "sunset": 1587168527,
#             "temp": {
#                 "day": 295.34,
#                 "min": 283.27,
#                 "max": 296.6,
#                 "night": 290.43,
#                 "eve": 292.98,
#                 "morn": 283.27
#             },
#             "feels_like": {
#                 "day": 292.04,
#                 "night": 289.17,
#                 "eve": 291.19,
#                 "morn": 280.22
#             },
#             "pressure": 1019,
#             "humidity": 46,
#             "dew_point": 284.58,
#             "wind_speed": 4.78,
#             "wind_deg": 179,
#             "weather": [
#                 {
#                     "id": 501,
#                     "main": "Rain",
#                     "description": "moderate rain",
#                     "icon": "10d"
#                 }
#             ],
#             "clouds": 88,
#             "rain": 4.09,
#             "uvi": 9.02
#         },
#         {
#             "dt": 1587229200,
#             "sunrise": 1587207680,
#             "sunset": 1587254972,
#             "temp": {
#                 "day": 291.6,
#                 "min": 283.52,
#                 "max": 292.38,
#                 "night": 283.52,
#                 "eve": 287.71,
#                 "morn": 288.83
#             },
#             "feels_like": {
#                 "day": 285.46,
#                 "night": 280.13,
#                 "eve": 283.09,
#                 "morn": 284.57
#             },
#             "pressure": 1016,
#             "humidity": 25,
#             "dew_point": 271.9,
#             "wind_speed": 5.56,
#             "wind_deg": 320,
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": 83,
#             "uvi": 8.73
#         },
#         {
#             "dt": 1587315600,
#             "sunrise": 1587294009,
#             "sunset": 1587341418,
#             "temp": {
#                 "day": 294.49,
#                 "min": 280.74,
#                 "max": 294.49,
#                 "night": 287.36,
#                 "eve": 290.2,
#                 "morn": 280.74
#             },
#             "feels_like": {
#                 "day": 290.77,
#                 "night": 285.88,
#                 "eve": 287.36,
#                 "morn": 276.71
#             },
#             "pressure": 1015,
#             "humidity": 26,
#             "dew_point": 275.3,
#             "wind_speed": 2.7,
#             "wind_deg": 180,
#             "weather": [
#                 {
#                     "id": 500,
#                     "main": "Rain",
#                     "description": "light rain",
#                     "icon": "10d"
#                 }
#             ],
#             "clouds": 42,
#             "rain": 1.08,
#             "uvi": 7.29
#         },
#         {
#             "dt": 1587402000,
#             "sunrise": 1587380339,
#             "sunset": 1587427864,
#             "temp": {
#                 "day": 296.43,
#                 "min": 287.84,
#                 "max": 297.27,
#                 "night": 288.55,
#                 "eve": 292.54,
#                 "morn": 287.84
#             },
#             "feels_like": {
#                 "day": 292.73,
#                 "night": 285.82,
#                 "eve": 289.09,
#                 "morn": 286.88
#             },
#             "pressure": 1010,
#             "humidity": 35,
#             "dew_point": 281.65,
#             "wind_speed": 4.27,
#             "wind_deg": 299,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": 4,
#             "uvi": 7.64
#         },
#         {
#             "dt": 1587488400,
#             "sunrise": 1587466669,
#             "sunset": 1587514311,
#             "temp": {
#                 "day": 299.46,
#                 "min": 287.67,
#                 "max": 299.76,
#                 "night": 294.56,
#                 "eve": 294.56,
#                 "morn": 287.67
#             },
#             "feels_like": {
#                 "day": 297.06,
#                 "night": 293.48,
#                 "eve": 293.48,
#                 "morn": 286.07
#             },
#             "pressure": 1016,
#             "humidity": 25,
#             "dew_point": 279.29,
#             "wind_speed": 1.74,
#             "wind_deg": 251,
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": 0,
#             "uvi": 8.12
#         }
#     ]
# }

# %%
temp = response_json['daily'][0]['temp']['day']
temp
# Out:
# 285.24

# %%
humidity = response_json['daily'][0]['humidity']
humidity
date1 = response_json['daily'][0]['dt']
date1
# Out:
# 1586883600

# %%
response_json['daily']
# Out:
# [{'dt': 1586710800,
#   'sunrise': 1586689721,
#   'sunset': 1586736300,
#   'temp': {'day': 291.36,
#    'min': 291.36,
#    'max': 294.42,
#    'night': 294.42,
#    'eve': 293.97,
#    'morn': 291.36},
#   'feels_like': {'day': 290.59,
#    'night': 291.16,
#    'eve': 291.95,
#    'morn': 290.59},
#   'pressure': 1009,
#   'humidity': 100,
#   'dew_point': 291.36,
#   'wind_speed': 5.22,
#   'wind_deg': 126,
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'clouds': 90,
#   'rain': 7.26,
#   'uvi': 9.04},
#  {'dt': 1586797200,
#   'sunrise': 1586776046,
#   'sunset': 1586822745,
#   'temp': {'day': 295.27,
#    'min': 284.7,
#    'max': 295.27,
#    'night': 284.7,
#    'eve': 288.75,
#    'morn': 290.1},
#   'feels_like': {'day': 290.93,
#    'night': 281.19,
#    'eve': 285.58,
#    'morn': 284.85},
#   'pressure': 1013,
#   'humidity': 42,
#   'dew_point': 283.12,
#   'wind_speed': 5.74,
#   'wind_deg': 286,
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': 0,
#   'uvi': 9.75},
#  {'dt': 1586883600,
#   'sunrise': 1586862371,
#   'sunset': 1586909190,
#   'temp': {'day': 296.29,
#    'min': 282.48,
#    'max': 296.92,
#    'night': 285.54,
#    'eve': 292.02,
#    'morn': 282.48},
#   'feels_like': {'day': 294.7, 'night': 281.81, 'eve': 288.85, 'morn': 279.33},
#   'pressure': 1017,
#   'humidity': 34,
#   'dew_point': 280.82,
#   'wind_speed': 1.09,
#   'wind_deg': 194,
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': 24,
#   'uvi': 9.94},
#  {'dt': 1586970000,
#   'sunrise': 1586948697,
#   'sunset': 1586995636,
#   'temp': {'day': 291.74,
#    'min': 282.8,
#    'max': 292.34,
#    'night': 282.93,
#    'eve': 287.23,
#    'morn': 282.8},
#   'feels_like': {'day': 286.68,
#    'night': 278.34,
#    'eve': 281.85,
#    'morn': 278.23},
#   'pressure': 1015,
#   'humidity': 27,
#   'dew_point': 273.63,
#   'wind_speed': 4.24,
#   'wind_deg': 311,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': 61,
#   'uvi': 8.95},
#  {'dt': 1587056400,
#   'sunrise': 1587035024,
#   'sunset': 1587082081,
#   'temp': {'day': 292.36,
#    'min': 282.36,
#    'max': 293.5,
#    'night': 285.06,
#    'eve': 289.1,
#    'morn': 282.36},
#   'feels_like': {'day': 288.92,
#    'night': 281.01,
#    'eve': 285.53,
#    'morn': 278.72},
#   'pressure': 1021,
#   'humidity': 32,
#   'dew_point': 276.67,
#   'wind_speed': 2.55,
#   'wind_deg': 118,
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': 3,
#   'uvi': 8.99},
#  {'dt': 1587142800,
#   'sunrise': 1587121352,
#   'sunset': 1587168527,
#   'temp': {'day': 292.02,
#    'min': 281.96,
#    'max': 294.62,
#    'night': 281.96,
#    'eve': 289.19,
#    'morn': 283.45},
#   'feels_like': {'day': 289.26, 'night': 277.09, 'eve': 285.4, 'morn': 280.6},
#   'pressure': 1015,
#   'humidity': 63,
#   'dew_point': 286.08,
#   'wind_speed': 4.68,
#   'wind_deg': 223,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': 99,
#   'uvi': 9.03},
#  {'dt': 1587229200,
#   'sunrise': 1587207680,
#   'sunset': 1587254972,
#   'temp': {'day': 289.44,
#    'min': 279.58,
#    'max': 290.95,
#    'night': 282.53,
#    'eve': 286.82,
#    'morn': 279.58},
#   'feels_like': {'day': 284.25,
#    'night': 279.59,
#    'eve': 283.15,
#    'morn': 273.05},
#   'pressure': 1021,
#   'humidity': 27,
#   'dew_point': 269.31,
#   'wind_speed': 4.05,
#   'wind_deg': 345,
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': 0,
#   'uvi': 8.64},
#  {'dt': 1587315600,
#   'sunrise': 1587294009,
#   'sunset': 1587341418,
#   'temp': {'day': 292.51,
#    'min': 280.43,
#    'max': 293.27,
#    'night': 287.57,
#    'eve': 290.16,
#    'morn': 280.43},
#   'feels_like': {'day': 287.9, 'night': 286.16, 'eve': 287.31, 'morn': 276.97},
#   'pressure': 1016,
#   'humidity': 32,
#   'dew_point': 276.56,
#   'wind_speed': 4.25,
#   'wind_deg': 170,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': 83,
#   'uvi': 7.59}]

# %%
city_name = 'tsihombe'

url_test = f'http://api.openweathermap.org/data/2.5/weather?q={city_name}&appid={weather_api_key}'
omg = requests.get(url_test).json()
omg
# Out:
# {'cod': '404', 'message': 'city not found'}

# %%
latitude = omg['coord']['lat']
latitude
# Out:
# 33.75

# %%
longitude = omg['coord']['lon']
longitude
# Out:
# -84.39
